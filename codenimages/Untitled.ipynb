# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import cv2
from skimage import data
from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.measure import label, regionprops
from skimage.morphology import closing, square
from skimage.color import label2rgb
from skimage import morphology as m

# %%
img = io.imread("adaptivethreshold1.jpg")


img_inv = cv2.bitwise_not( img )
io.imsave("noise.png", img_inv)
text_threshold = filters.threshold_local(img_inv,block_size=5, offset=10) 
io.imsave("noise.png", img_inv)
io.imshow(text_threshold)
io.show()

# %%
text_threshold = filters.threshold_local(text,block_size=51, offset=10)

# %%
from skimage import data
from skimage import filters
import cv2
img = io.imread("aaa.jpg")
# Out:
# array([[[181, 166,   5],
#         [181, 166,   5],
#         [181, 166,   5],
#         ...,
#         [179, 161,   1],
#         [179, 161,   1],
#         [179, 161,   1]],
#
#        [[179, 164,   3],
#         [179, 164,   3],
#         [180, 165,   4],
#         ...,
#         [179, 161,   1],
#         [179, 161,   1],
#         [179, 161,   1]],
#
#        [[177, 162,   1],
#         [178, 163,   2],
#         [180, 165,   4],
#         ...,
#         [179, 161,   1],
#         [179, 161,   1],
#         [179, 161,   1]],
#
#        ...,
#
#        [[170, 150,   1],
#         [170, 150,   1],
#         [170, 150,   1],
#         ...,
#         [162, 141,   0],
#         [162, 141,   0],
#         [162, 141,   0]],
#
#        [[170, 150,   1],
#         [170, 150,   1],
#         [170, 150,   1],
#         ...,
#         [162, 141,   0],
#         [162, 141,   0],
#         [162, 141,   0]],
#
#        [[170, 150,   1],
#         [170, 150,   1],
#         [170, 150,   1],
# ...
